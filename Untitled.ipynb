# %%
from bs4 import BeautifulSoup
import urllib2
from selenium import webdriver

# %%
driver = webdriver.PhantomJS(executable_path=r'D:\Anaconda2\Tools\phantomjs-2.1.1-windows\bin\phantomjs.exe')

# %%
driver.get('http://www.tianyancha.com/company/3019250186')

# %%
data = driver.find_element_by_class_name('ng-scope').text

# %%
print data
# Out:
# 中国建设银行股份有限公司
# 企业信用报告
#
# 电话: 0510-87871970 邮箱: 001@wx-w.com
# 网址: 暂无
# 地址: 宜兴市和桥镇昌溪桥西侧
# 立即更新
# 天眼查数据更新时间
# 2017.03.20
# 分享
# 企业背景
# 基本信息
# 企业关系
# 主要人员 16
# 股东信息 5
# 对外投资 40
# 变更记录 1
# 企业年报 3
# 分支机构 99+
# 企业发展
# 融资历史 0
# 核心团队 0
# 企业业务 1
# 投资事件 0
# 竞品信息 17
# 司法风险
# 法律诉讼 99+
# 法院公告 99+
# 失信人 0
# 被执行人 0
# 经营风险
# 经营异常 0
# 行政处罚 0
# 严重违法 0
# 股权出质 0
# 动产抵押 0
# 欠税公告 0
# 经营状况
# 招投标 99+
# 债券信息 51
# 购地信息 0
# 招聘 0
# 税务评级 0
# 抽查检查 1
# 产品信息 0
# 资质证书 0
# 知识产权
# 商标信息 99+
# 专利 99+
# 著作权 99+
# 网站备案 0
# 企业背景
# 基本信息
# 法定代表人
# 徐法坤 他的所有公司
# 注册资本
# 300万元人民币
# 注册时间
# 1993-07-12
# 状态
# 在业
# 工商注册号：320282000087429
# 组织机构代码：25047652X
# ［ 以上评分结果仅供参考 ］
# 统一信用代码：9132028225047652X8
# 企业类型：有限责任公司
# 行业：专用设备制造业
# 营业期限： 1997-05-19至2021-10-15
# 核准日期： 2016-04-11
# 登记机关：宜兴市市场监督管理局
# 注册地址：宜兴市和桥镇昌溪桥西侧
# 经营范围： 喷泉设备及配件、环境污染防治设备的制造、销售。（依法须经批准的项目，经相关部门批准后方可开展经营活动）
# 主要人员16
# 刘进
# 监事
# 李军
# 董事
# 白建军
# 监事
# 李晓玲
# 监事
# 李振宇
# 监事
# 郭友
# 监事会主席
# 王洪章
# 董事长
# 李秀昆
# 监事
# 董轼
# 董事
# 郝爱群
# 董事
# 冯婉眉
# 独立董事
# 靳彦民
# 监事
# 郭衍鹏
# 董事
# 莫里.洪恩
# ...

# %%
type(data)
# Out:
# unicode

# %%
len(data)
# Out:
# 1846

# %%
data[1]
# Out:
# u'\u4efd'

# %%
print data[:10]
# Out:
# 省份地区
# 北京
# 天津
