# %%
from selenium import webdriver

# %%
progPath = r"D:\Anaconda2\Tools\phantomjs-2.1.1-windows\bin\phantomjs.exe"
driver = webdriver.PhantomJS(executable_path=progPath)

# %%
driver.get('http://www.tianyancha.com/company/589766337')

# %%
xpath = "//div[@class='company_info_text']/div[@class='in-block ml10 f18 mb5 ng-binding']"

# %%
a = driver.find_element_by_xpath(xpath)
driver.fin

# %%
print a.text
# Out:
# 青海玉树农村商业银行股份有限公司

# %%
xpath_1 = "//tr[1]/td[@class='basic-td'][1]/div[@class='c8']"

# %%
b = driver.find_element_by_xpath(xpath_1)

# %%
print b.text
# Out:
# 工商注册号：3204813805356

# %%
print(driver.page_source,file=open('C:/Users/Administrator/Desktop/source.html','w'))
# Out:
#   File "<ipython-input-22-8f02a687851a>", line 1
#     print(driver.page_source,file=open('C:/Users/Administrator/Desktop/source.html','w'))
#                                  ^
# SyntaxError: invalid syntax

# %%
print(driver.page_source, file=open('C:/Users/Administrator/Desktop/source.html', 'w'))
# Out:
#   File "<ipython-input-23-c915b4d689d9>", line 1
#     print(driver.page_source, file=open('C:/Users/Administrator/Desktop/source.html', 'w'))
#                                   ^
# SyntaxError: invalid syntax

# %%
f = open('C:/Users/Administrator/Desktop/source.html', 'w', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-bfb5428cadd0> in <module>()
# ----> 1 f = open('C:/Users/Administrator/Desktop/source.html', 'w', encoding='utf-8')
#
# TypeError: 'encoding' is an invalid keyword argument for this function

# %%
print(driver.page_source, file=f)
# Out:
#   File "<ipython-input-26-3e9c0e2c71d7>", line 1
#     print(driver.page_source, file=f)
#                                   ^
# SyntaxError: invalid syntax

# %%
f.write(driver.page_source.encode('utf-8').decode())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-35-ec76c7a05b85> in <module>()
# ----> 1 f.write(driver.page_source.encode('utf-8').decode())
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe4 in position 1013: ordinal not in range(128)

# %%
print driver.page_source
# Out:
# <!DOCTYPE html><html xmlns:ng="http://angularjs.org" id="ng-app" class="ng-app:app ng-scope" ng-app="app"><head><!--[if IE 8]><style>.ng-hide {display: none !important;}</style><![endif]--><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style><script charset="utf-8" src="https://tag.baidu.com/vcard/v.js?siteid=8033946&amp;url=http%3A%2F%2Fwww.tianyancha.com%2Fcompany%2F589766337&amp;source=&amp;rnd=1473596919&amp;hm=1"></script><script type="text/javascript" async="" defer="" src="//www.tianyancha.com/piwik/piwik.js"></script><script src="//hm.baidu.com/hm.js?e92c8d65d92d534b0fc290df538b4758"></script><script async="" src="http://qzs.qq.com/qzone/biz/res/gt.js"></script><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><title ng-bind-html="
# ...

# %%
driver.save_screenshot('screenshot.png')
# Out:
# True

# %%
dcap = dict(webdriver.DesiredCapabilities.PHANTOMJS)
dcap["phantomjs.page.settings.userAgent"] = ("Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.63 Safari/537.36")
service_args = ['--load-images=false', '--proxy-type=None']
driver = webdriver.PhantomJS(executable_path=progPath, service_args=service_args, desired_capabilities=dcap)
driver.get('http://www.tianyancha.com/company/589766337')
print driver.current_url
# Out:
# http://www.tianyancha.com/company/589766337

# %%
driver.save_screenshot('screenshot.png')
# Out:
# True
